# %%
# 직원 순환 배치 PPO 강화학습
import datetime
import pandas as pd
import numpy as np
import torch
import gym
from gym import spaces
from stable_baselines3 import PPO
from sklearn.metrics.pairwise import euclidean_distances
import warnings
warnings.filterwarnings("ignore")

# 1. 실험 재현성을 위한 난수 시드(SEED) 고정
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# 2. 직원 및 지점 정보를 CSV 파일에서 로드
employees = pd.read_csv("./data/rotation_employees.csv")
branches = pd.read_csv("./data/rotation_branches.csv")

# 3. 근무 기간에 따라 순환 배치 대상 직원(eligible)과 비대상 직원(non-eligible) 분류
eligible_employees = employees[employees['years_at_branch'] > 3].reset_index(drop=True)
non_eligible_employees = employees[employees['years_at_branch'] <= 3].copy()
non_eligible_employees['new_branch'] = non_eligible_employees['current_branch']
non_eligible_employees['reassigned'] = False

# 4. 강화학습 환경에서 사용할 지점명 리스트 준비
branch_names = branches['branch_name'].tolist()

# 5. 직원의 집과 각 지점 간의 유클리드 거리를 계산하는 함수 정의하고, 이를 이용해 거리 행렬 생성
def calculate_distance_matrix(emp_df, branch_df):
    home_coords = emp_df[['home_x', 'home_y']].values
    branch_coords = branch_df[['branch_x', 'branch_y']].values
    return euclidean_distances(home_coords, branch_coords)
    
distance_matrix = calculate_distance_matrix(eligible_employees, branches)

# 6. 직원 순환 배치 문제를 위한 사용자 정의 Gym 환경('RotationEnv') 정의
class RotationEnv(gym.Env):

    # 7. 환경 초기화 메서드: 필요한 데이터, 공간 정의, 상태 변수 초기화 등 수행
    def __init__(self, emp_df, branch_df, distance_matrix, full_emp_df): # ranks 파라미터 제거
        super().__init__()
        self.emp_df = emp_df  # 이동 대상 직원
        self.branch_df = branch_df # 지점 정보
        self.distance_matrix = distance_matrix # 거리 행렬

        self.n_emp = len(emp_df) # 이동 대상 직원 수
        self.n_branches = len(branch_df) # 지점 수
        self.max_branch_capacity = 12 # 지점 최대 정원
        self.min_branch_capacity = 8  # 지점 최소 정원

        # 7.1 에이전트가 배치함에 따라 변경될 지점별 인원 현황
        self.branch_counts = np.zeros(self.n_branches, dtype=int)
        self.current_idx = 0 # 현재 배치 중인 이동 대상 직원의 인덱스

        # 7.2 이동 비대상 직원(고정 인원)으로 인한 초기 지점 상태(인원수) 설정
        self.fixed_branch_counts = self._init_branch_state(full_emp_df) # _init_branch_state 반환값 변경에 따름

        # 7.3 행동 공간(Action Space) 정의: 에이전트는 각 직원에 대해 n_branches개의 지점 중 하나 선택
        self.action_space = spaces.Discrete(self.n_branches)
        
        # 7.4 관찰 공간(Observation Space) 정의: 직급 분포 정보 제거
        # 구성: [현재 직원 집 좌표(2), 지점별 수용력 비율(n_branches)]
        self.observation_space = spaces.Box(low=0, high=1, shape=(2 + self.n_branches,), dtype=np.float32)

    # 8. (내부 메서드) 전체 직원 데이터를 기반으로 고정된 초기 지점 상태(총 인원) 계산
    def _init_branch_state(self, full_df): # 반환값에서 rank_counts 제거
        counts = np.zeros(self.n_branches, dtype=int)
        for _, row in full_df.iterrows():
            idx = self.branch_df[self.branch_df['branch_name'] == row['current_branch']].index[0]
            counts[idx] += 1
        return counts # counts만 반환

    # 9. (Gym 표준 메서드) 환경의 난수 시드 설정
    def seed(self, seed=None):
        np.random.seed(seed)
        return [seed]

    # 10. (Gym 표준 메서드) 에피소드 시작 시 환경을 초기 상태로 리셋하고 첫 관찰 값 반환
    def reset(self):
        self.emp_df = self.emp_df.sample(frac=1).reset_index(drop=True) # 직원 순서 섞기
        self.current_idx = 0
        self.branch_counts[:] = 0 # 이번 에피소드 배치 현황 초기화

        return self._get_obs()

    # 11. (내부 메서드) 현재 상태에 대한 관찰 값을 생성하여 에이전트에게 제공
    def _get_obs(self):
        emp = self.emp_df.iloc[self.current_idx]
        home_xy = np.array([emp['home_x'] / 100.0, emp['home_y'] / 100.0])

        total_counts = self.fixed_branch_counts + self.branch_counts
        capacity_ratio = total_counts / self.max_branch_capacity

        return np.concatenate([home_xy, capacity_ratio], axis=0).astype(np.float32)

    # 12. (내부 메서드) 에이전트의 행동(action)에 대한 보상(reward) 계산. 직급 관련 패널티 로직 제거.
    def _calculate_reward(self, action, emp): # rank 파라미터 제거
        # 12-1 보상 점수를 매기기 위한 기초 정보를 준비
        projected_count = self.fixed_branch_counts[action] + self.branch_counts[action] + 1 #그 지점의 예상 총 인원
        total_required = self.min_branch_capacity * self.n_branches                         #모든 지점에 필요한 최소 총 인원
        assigned_so_far = self.current_idx + 1                                              #지금까지 보낸 직원 수
        progress_ratio = assigned_so_far / total_required if total_required > 0 else 0      #전체 배치 중 얼마나 진행됐는지 비율

        # 12-2 필수 이동 대상자(4년 이상 근무)가 원래 지점에 남는 경우 패널티 (배치 진행률 60% 이상 시 적용)
        moved_required_penalty = 0
        if emp['years_at_branch'] >= 4 and emp['current_branch'] == self.branch_df.iloc[action]['branch_name']:
            if progress_ratio >= 0.6:
                moved_required_penalty = 1

        # 12-3 정원 초과 & 미달 패널티 설정
        over_penalty = 0
        under_penalty = 0
        if projected_count > self.max_branch_capacity: # 정원 초과 패널티
            over_penalty = projected_count - self.max_branch_capacity
        elif projected_count < self.min_branch_capacity: # 정원 미달 패널티 (배치 진행률 60% 이상 시 적용)
            if progress_ratio >= 0.6:
                under_penalty = self.min_branch_capacity - projected_count
        
        # 12-4 최종 보상 계산: 각 패널티 항목에 가중치 부여
        reward = \
            - 1 * over_penalty  \
            - 4 * under_penalty  \
            - 2 * moved_required_penalty
        return reward

    # 13. (Gym 표준 메서드) 에이전트가 행동을 취하면, 환경 상태를 업데이트하고 다음 관찰, 보상, 종료 여부 등을 반환
    def step(self, action):
        # 13.1 현재 직원 정보 가져오고, 선택한 행동에 대한 점수 매기기
        emp = self.emp_df.iloc[self.current_idx]
        reward = self._calculate_reward(action, emp)

        # 13.2 선택된 지점에 현재 직원 배치 및 상태 업데이트
        self.branch_counts[action] += 1
        self.current_idx += 1 # 다음 직원으로 이동

        # 13.3 모든 이동 대상 직원 배치 완료 시 에피소드 종료
        done = self.current_idx >= self.n_emp  

        #13.4 다음 상황판 정보 만들고, 이번 행동의 최종 결과들 돌려주기
        obs = self._get_obs() if not done else np.zeros(self.observation_space.shape, dtype=np.float32)
        return obs, reward, done, {}

# 14. 정의한 RotationEnv 환경의 인스턴스 생성
env = RotationEnv(eligible_employees, branches, distance_matrix, full_emp_df=employees)

# 15. PPO 모델의 정책 신경망 아키텍처 및 활성화 함수 등 추가 설정 정의
policy_kwargs = dict(activation_fn=torch.nn.SiLU, 
                     net_arch=[dict(pi=[128,64], vf=[128,32])] # 정책망(pi), 가치망(vf) 구조
                    )

# 16. PPO 강화학습 모델 초기화. 주요 하이퍼파라미터(학습률, 엔트로피 계수 등) 설정
model = PPO(
    "MlpPolicy", # 다층 퍼셉트론(MLP) 기반 정책 사용
    env, 
    learning_rate=0.00005, # 학습률
    ent_coef=0.1,          # 엔트로피 계수 (탐험 장려)
    clip_range=0.2,        # PPO 클리핑 범위
    vf_coef=0.2,           # 가치 함수 손실 가중치
    policy_kwargs=policy_kwargs, # 신경망 설정
    seed=SEED,             # 재현성을 위한 시드
    verbose=1              # 학습 진행 상황 출력 레벨
)

# 17. PPO 모델 학습 시작
model.learn(total_timesteps=1_500_000, log_interval=20) # 총 학습 스텝 수, 로그 출력 간격

# 18. 학습된 모델 파일로 저장
model.save("./models/rotation_ppo_model") # 저장 파일명 변경하여 구분
print("**모델 학습 완료**")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | -22.3      |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 20         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00571423 |
# |    clip_fraction        | 0.00112    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.336      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 3.73       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00674   |
# |    value_loss           | 21.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -23.3        |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 40           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0024555502 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.534        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 1.57         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -21.6        |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 60           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0066949073 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 1.78         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 9.6          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -22.4       |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 80          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.012266668 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 1.49        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 9.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 100         |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.004754264 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.606       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 6.03        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | -19        |
# | time/                   |            |
# |    fps                  | 545        |
# |    iterations           | 120        |
# |    time_elapsed         | 450        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.01252351 |
# |    clip_fraction        | 0.088      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 1.12       |
# |    n_updates            | 1190       |
# |    policy_gradient_loss | -0.00908   |
# |    value_loss           | 7.69       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -18.6        |
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 140          |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0067552086 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.862        |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00441     |
# |    value_loss           | 6.09         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -17.7       |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 160         |
# |    time_elapsed         | 602         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.010869373 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.522       |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 3.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 180         |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.010819849 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.664       |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 4.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 200         |
# |    time_elapsed         | 749         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.010347681 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.248       |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -16.6       |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 220         |
# |    time_elapsed         | 822         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.010439481 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.37        |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 3.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -16.8       |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 240         |
# |    time_elapsed         | 893         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.009838078 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.713       |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00865    |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -16.4       |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 260         |
# |    time_elapsed         | 962         |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.010445829 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.403       |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -15.3       |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 280         |
# |    time_elapsed         | 1032        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.008992997 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.136       |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 1.98        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | -15.4      |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 300        |
# |    time_elapsed         | 1108       |
# |    total_timesteps      | 614400     |
# | train/                  |            |
# |    approx_kl            | 0.01134588 |
# |    clip_fraction        | 0.0886     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.09      |
# |    explained_variance   | 0.832      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.202      |
# |    n_updates            | 2990       |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 2.2        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -15.6       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 320         |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.008934642 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.166       |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 1.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 340         |
# |    time_elapsed         | 1274        |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.008296602 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0201     |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 1.42        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | -14.8      |
# | time/                   |            |
# |    fps                  | 544        |
# |    iterations           | 360        |
# |    time_elapsed         | 1353       |
# |    total_timesteps      | 737280     |
# | train/                  |            |
# |    approx_kl            | 0.00853579 |
# |    clip_fraction        | 0.0684     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.08      |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.269      |
# |    n_updates            | 3590       |
# |    policy_gradient_loss | -0.00924   |
# |    value_loss           | 2.73       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -14.4       |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 380         |
# |    time_elapsed         | 1432        |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.010700239 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0632      |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 2.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -14.2       |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 400         |
# |    time_elapsed         | 1506        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.011143302 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0711      |
# |    n_updates            | 3990        |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 420         |
# |    time_elapsed         | 1579        |
# |    total_timesteps      | 860160      |
# | train/                  |             |
# |    approx_kl            | 0.008298248 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0493      |
# |    n_updates            | 4190        |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 1.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -14.2       |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 440         |
# |    time_elapsed         | 1663        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.007835933 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0931      |
# |    n_updates            | 4390        |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -13.5        |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 460          |
# |    time_elapsed         | 1739         |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0059367446 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.00706      |
# |    n_updates            | 4590         |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 1.07         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | -13.7      |
# | time/                   |            |
# |    fps                  | 543        |
# |    iterations           | 480        |
# |    time_elapsed         | 1807       |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.00897925 |
# |    clip_fraction        | 0.0806     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.03      |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.041      |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | -0.00869   |
# |    value_loss           | 1.11       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 500         |
# |    time_elapsed         | 1874        |
# |    total_timesteps      | 1024000     |
# | train/                  |             |
# |    approx_kl            | 0.009141218 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0621     |
# |    n_updates            | 4990        |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 1.02        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -13.2        |
# | time/                   |              |
# |    fps                  | 548          |
# |    iterations           | 520          |
# |    time_elapsed         | 1941         |
# |    total_timesteps      | 1064960      |
# | train/                  |              |
# |    approx_kl            | 0.0060538976 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0544      |
# |    n_updates            | 5190         |
# |    policy_gradient_loss | -0.000848    |
# |    value_loss           | 0.918        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 540         |
# |    time_elapsed         | 2011        |
# |    total_timesteps      | 1105920     |
# | train/                  |             |
# |    approx_kl            | 0.009359336 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0333      |
# |    n_updates            | 5390        |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 560         |
# |    time_elapsed         | 2083        |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.008057587 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0708      |
# |    n_updates            | 5590        |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 1.08        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -12.8        |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 580          |
# |    time_elapsed         | 2150         |
# |    total_timesteps      | 1187840      |
# | train/                  |              |
# |    approx_kl            | 0.0069799055 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.99        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0915      |
# |    n_updates            | 5790         |
# |    policy_gradient_loss | -0.00756     |
# |    value_loss           | 0.695        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 600         |
# |    time_elapsed         | 2221        |
# |    total_timesteps      | 1228800     |
# | train/                  |             |
# |    approx_kl            | 0.008071276 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.162      |
# |    n_updates            | 5990        |
# |    policy_gradient_loss | -0.00774    |
# |    value_loss           | 0.583       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | -12.8      |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 620        |
# |    time_elapsed         | 2295       |
# |    total_timesteps      | 1269760    |
# | train/                  |            |
# |    approx_kl            | 0.00995245 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.01      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.138     |
# |    n_updates            | 6190       |
# |    policy_gradient_loss | -0.0106    |
# |    value_loss           | 0.492      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -12.6       |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 640         |
# |    time_elapsed         | 2365        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.006093004 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.117      |
# |    n_updates            | 6390        |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 0.615       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | -12.5        |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 660          |
# |    time_elapsed         | 2426         |
# |    total_timesteps      | 1351680      |
# | train/                  |              |
# |    approx_kl            | 0.0043772664 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0942      |
# |    n_updates            | 6590         |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 0.529        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 559         |
# |    iterations           | 680         |
# |    time_elapsed         | 2488        |
# |    total_timesteps      | 1392640     |
# | train/                  |             |
# |    approx_kl            | 0.008886259 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.117      |
# |    n_updates            | 6790        |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 0.533       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -12.2       |
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 700         |
# |    time_elapsed         | 2550        |
# |    total_timesteps      | 1433600     |
# | train/                  |             |
# |    approx_kl            | 0.008375665 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0913     |
# |    n_updates            | 6990        |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 0.659       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 720         |
# |    time_elapsed         | 2612        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.008910481 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.139      |
# |    n_updates            | 7190        |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.476       |
# -----------------------------------------
# **모델 학습 완료 (직급 분배 로직 없음)**

# %%
# ---------------------------
# 예측 및 결과 저장
# ---------------------------
# 1. 이전에 학습하고 저장한 PPO 모델 로딩
model = PPO.load("./models/rotation_ppo_model")

# 2. 평가(예측)를 위해 직원 및 지점 정보 로드
employees = pd.read_csv("./data/rotation_employees.csv")  # 직원 정보
branches = pd.read_csv("./data/rotation_branches.csv")    # 지점 정보

# 3. PyTorch가 결정론적 알고리즘을 사용하도록 설정
torch.use_deterministic_algorithms(True)

# 4. 이동 대상 직원 목록을 특정 random_state로 재구성
eligible_employees = eligible_employees.sample(frac=1, random_state=42).reset_index(drop=True)

# 5. 평가를 위한 RotationEnv 환경 인스턴스 생성 및 환경 리셋
env_eval = RotationEnv(eligible_employees, branches, distance_matrix, full_emp_df=employees)
obs = env_eval.reset()

# 6. 각 이동 대상 직원에 대한 예측된 배치 결과를 저장할 리스트 초기화
assignments = []

while True:

    # 7. 학습된 모델을 사용하여 현재 관찰(obs)에 대한 최적의 행동(action, 즉 배치할 지점)을 예측
    action, _ = model.predict(obs, deterministic=False) 
    
    # 8. 예측된 행동(지점 인덱스) 출력
    print(action, end=', ')
    
    # 9. 예측된 행동을 assignments 리스트 추가
    assignments.append(int(action))
    
    # 10. 환경에서 해당 행동을 실행하고, 다음 관찰(obs), 보상(_), 종료 여부(done) 등의 정보 수신
    obs, _, done, _ = env_eval.step(action)
    
    # 11. 모든 직원이 배치되었으면(done=True) 루프 종료
    if done:
        break

# 12. 이동 대상 직원(eligible_employees) DataFrame에 예측된 'new_branch'(새 지점) 정보 추가
eligible_employees_eval['new_branch'] = [branch_names[a] for a in assignments]

# 13. 이동 대상 직원들은 재배치되었음을 표시
eligible_employees_eval['reassigned'] = True

# 14. 이동 대상 직원 결과와 이동 비대상 직원 정보를 합쳐 최종 배치 DataFrame을 생성하고, 직원 ID 순으로 정렬합니다.
final_df = pd.concat([eligible_employees_eval, non_eligible_employees], ignore_index=True).sort_values(by='employee_id')

# 15. 현재 날짜와 시간을 포함한 파일명으로 최종 배치 결과를 CSV 파일로 저장
filename = f"./data/rotation_assignments_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
final_df.to_csv(filename, index=False, encoding='utf-8-sig') # UTF-8(BOM) 인코딩으로 Excel 호환성 향상

print(f"*최종 발령표 저장 완료: {filename}")

# ---------------------------
# 결과 점검 출력
# ---------------------------
# 16. 순환 배치 전(Old) 지점별, 직급별 인원 현황을 집계하여 출력
branch_summary_old = final_df.groupby(['current_branch', 'rank']).size().unstack(fill_value=0)
branch_summary_old['합계'] = branch_summary_old.sum(axis=1)
print("*지점별 인원배분 점검 Old (직급별 + 총합)")
print(branch_summary_old)

# 17. 순환 배치 후(New) 지점별, 직급별 인원 현황을 집계하여 출력
branch_summary_new = final_df.groupby(['new_branch', 'rank']).size().unstack(fill_value=0)
branch_summary_new['합계'] = branch_summary_new.sum(axis=1)
print("*지점별 인원배분 점검 New (직급별 + 총합)")
print(branch_summary_new)

moved_4yrs_eligible_ids = eligible_employees_eval['employee_id']
moved_4yrs_check_df = final_df[(final_df['employee_id'].isin(moved_4yrs_eligible_ids)) & (final_df['years_at_branch'] >= 4)].copy()

if not moved_4yrs_check_df.empty:
    # 18. 이동 대상이면서 4년 이상 근무한 직원들의 실제 이동 여부 분석
    moved_4yrs_check_df['moved'] = moved_4yrs_check_df['current_branch'] != moved_4yrs_check_df['new_branch']
    moved_summary = moved_4yrs_check_df['moved'].value_counts(dropna=False).rename(index={True: '이동함', False: '이동 안함', np.nan: '해당없음'})
    print("*4년 이상 근무한 '이동 대상' 직원의 부서 이동 여부:")
    print(moved_summary)

    # 19. 만약 이동해야 하는 4년 이상 근무자 중 이동하지 않은 인원이 있다면, 해당 직원 정보 출력
    not_moved_list = moved_4yrs_check_df[moved_4yrs_check_df['moved'] == False]
    if not not_moved_list.empty:
        print("*이동하지 않은 4년 이상 근무자 (이동 대상이었던 직원):")
        print(not_moved_list[['employee_id', 'current_branch', 'new_branch', 'years_at_branch', 'rank']])
    else:
        print("*모든 4년 이상 '이동 대상' 근무자는 부서 이동 완료 또는 대상자 없음")
else:
    print("*4년 이상 근무한 '이동 대상' 직원이 없습니다.")
# Out:
# 4, 0, 5, 7, 8, 1, 8, 5, 2, 0, 4, 3, 8, 7, 5, 6, 7, 7, 8, 2, 2, 4, 7, 8, 3, 5, 2, 0, 8, 7, *최종 발령표 저장 완료: ./data/rotation_assignments_20250519_171453.csv
# *지점별 인원배분 점검 Old (직급별 + 총합)
# rank            과장  대리  사원  합계
# current_branch
# Branch_0         4   3   3  10
# Branch_1         4   4   3  11
# Branch_2         4   3   3  10
# Branch_3         4   4   3  11
# Branch_4         4   3   3  10
# Branch_5         3   3   3   9
# Branch_6         4   4   3  11
# Branch_7         3   3   2   8
# Branch_8         3   3   2   8
# Branch_9         4   4   4  12
# *지점별 인원배분 점검 New (직급별 + 총합)
# rank        과장  대리  사원  합계
# new_branch
# Branch_0     3   2   4   9
# Branch_1     5   2   0   7
# Branch_2     4   3   4  11
# Branch_3     4   5   3  12
# Branch_4     2   5   3  10
# Branch_5     3   5   2  10
# Branch_6     2   3   3   8
# Branch_7     5   4   3  12
# Branch_8     5   3   4  12
# Branch_9     4   2   3   9
# *4년 이상 근무한 '이동 대상' 직원의 부서 이동 여부:
# moved
# 이동함      24
# 이동 안함     6
# Name: count, dtype: int64
# *이동하지 않은 4년 이상 근무자 (이동 대상이었던 직원):
#     employee_id current_branch new_branch  years_at_branch rank
# 16            3       Branch_7   Branch_7                4   과장
# 19           11       Branch_2   Branch_2                9   과장
# 12           14       Branch_8   Branch_8                8   대리
# 14           41       Branch_5   Branch_5               10   사원
# 8            42       Branch_2   Branch_2                6   과장
# 6            97       Branch_8   Branch_8                7   대리

# %%
# 1. 지점의 문자열 명칭과 해당 지점 데이터의 숫자 인덱스 간의 상호 참조 가능한 매핑 구조 생성
branch_name_to_idx = {name: idx for idx, name in enumerate(branch_names)}

# 2. 순환 배치 적용 이전과 이후, 각 직원의 자택과 해당 근무 지점 간의 유클리드 거리를
# 개별적으로 저장하기 위한 리스트 변수를 초기화
past_distances, current_distances = [], []

# 3. 최종적으로 확정된 직원 배치 결과('final_df')를 한 명씩 순회하면서,
# 각 직원의 배치 전후 근무지와 자택 간의 거리 변화를 정량적으로 산출
for _, row in final_df.iterrows():
    
    # 3-1. 현재 순회 중인 직원의 자택 위치 좌표(x, y)를 NumPy 배열 형태로 추출
    home = np.array([row['home_x'], row['home_y']])
    
    # 3-2. 해당 직원의 순환 배치 이전 근무 지점명과 새로 배정된 지점명을 사용하여,
    # 앞서 생성한 'branch_name_to_idx' 매핑 테이블을 통해 각 지점의 고유 숫자 인덱스 조회
    past_idx = branch_name_to_idx[row['current_branch']]
    curr_idx = branch_name_to_idx[row['new_branch']]
    
    # 3-3. 조회된 숫자 인덱스를 활용하여 전체 지점 정보가 담긴 'branches' DataFrame에서
    # 해당 지점들의 물리적 위치 좌표(x, y) 추출
    past_loc = branches.iloc[past_idx][['branch_x', 'branch_y']].values
    curr_loc = branches.iloc[curr_idx][['branch_x', 'branch_y']].values

    # 3-4. 직원의 자택 좌표와 각 근무 지점(순환 배치 이전 및 현재)의 좌표 간의
    # 직선 거리, 즉 유클리드 거리를 'np.linalg.norm' 함수를 이용하여 계산
    # 이 함수는 두 벡터 차의 L2 노름(norm)을 계산함으로써 두 점 사이의 거리 나타냄
    past_distances.append(np.linalg.norm(home - past_loc))
    current_distances.append(np.linalg.norm(home - curr_loc))

# 4. 전 직원을 대상으로 산출된, 순환 배치 이전/이후 근무 지점까지의 개별 거리들의 산술 평균 계산
past_mean = np.mean(past_distances)
curr_mean = np.mean(current_distances)

# 5. 두 평균 거리 값의 차이를 계산하여, 이번 순환 배치가 전체 직원의 평균적인
# 자택-근무지 간 거리에 어떠한 변화를 야기했는지를 정량적으로 나타냄
diff = curr_mean - past_mean

print("\n과거 지점과 현재 배정 지점 간 거리 평균 비교:")
print(f"*과거 지점 평균 거리: {past_mean:.2f}")
print(f"*현재 배정 지점 평균 거리: {curr_mean:.2f}")

if diff < 0:
    print(f"*평균적으로 직원들의 출퇴근 거리가 {abs(diff):.2f}만큼 줄었습니다.")
else:
    print(f"*평균적으로 직원들의 출퇴근 거리가 {diff:.2f}만큼 늘었습니다.")
# Out:
# 과거 지점과 현재 배정 지점 간 거리 평균 비교:
# *과거 지점 평균 거리: 49.07
# *현재 배정 지점 평균 거리: 47.75
# *평균적으로 직원들의 출퇴근 거리가 1.32만큼 줄었습니다.

# %%
'''
각 지점 인원: 8~12명 사이
4년 이상 근무자의 전원 이동
평균 거리 감소 폭 ≥ 1 이상
'''
# 1. 최대 반복 시도 횟수 설정 및 성공 여부 플래그 초기화
max_attempts = 1000
success = False

for attempt in range(1, max_attempts + 1):
    print(attempt, end=", ") # 현재 시도 횟수 출력

    # 2. 각 시도마다 이동 대상 직원의 처리 순서를 무작위로 변경
    np.random.seed(None) # Pandas sample의 무작위성 확보
    eligible_employees_shuffled = eligible_employees.sample(frac=1).reset_index(drop=True)
    np.random.seed(SEED) # 기타 NumPy 연산의 재현성 확보
    
    env_eval = RotationEnv(eligible_employees_shuffled, branches, distance_matrix, ranks, full_emp_df=employees)
    obs = env_eval.reset()
    model = PPO.load("./models/rotation_ppo_model")

    # 3. 준비된 환경과 모델을 사용하여 이동 대상 직원들의 새로운 지점 배치를 순차적으로 예측
    assignments = []
    while True:
        action, _ = model.predict(obs) # deterministic=False (기본값)으로 정책에 따른 샘플링
        assignments.append(int(action))
        obs, _, done, _ = env_eval.step(action) # 환경 상태 업데이트
        if done: # 모든 직원이 배치되면 종료
            break

    # 4. 예측된 배치 결과를 바탕으로 최종 발령표(DataFrame)를 구성
    eligible_employees_shuffled['new_branch'] = [branch_names[a] for a in assignments]
    eligible_employees_shuffled['reassigned'] = True
    final_df = pd.concat([eligible_employees_shuffled, non_eligible_employees], ignore_index=True).sort_values(by='employee_id')

    # 5. 생성된 배치안이 사전에 정의된 운영상의 필수 조건들을 만족하는지 검증
    # 5-1. 지점 인원 수 조건 검증
    branch_counts = final_df['new_branch'].value_counts()
    if not branch_counts.between(8, 12).all():
        print(f"❌ 조건 불만족 (시도 {attempt}): 지점별 인원 범위(8~12명) 이탈")
        continue

    # 5-2. 4년 이상 근무자 이동 조건 검증
    moved_4yrs_subset = eligible_employees_shuffled[eligible_employees_shuffled['years_at_branch'] >= 4].copy()
    if not moved_4yrs_subset.empty:
        moved_4yrs_subset['moved'] = moved_4yrs_subset['current_branch'] != moved_4yrs_subset['new_branch']
        if not moved_4yrs_subset['moved'].all():
            print(f"❌ 조건 불만족 (시도 {attempt}): 4년 이상 근무자 미이동 발생")
            continue
    
    # 5-3. 평균 거리 조건 검증 (현재 로직: 새 평균 거리가 이전 평균보다 1 이상 크게 늘어나지 않아야 함)
    past_distances, current_distances = [], []
    branch_name_to_idx = {name: idx for idx, name in enumerate(branch_names)}
    for _, row in final_df.iterrows():
        home = np.array([row['home_x'], row['home_y']])
        past_idx = branch_name_to_idx[row['current_branch']]
        curr_idx = branch_name_to_idx[row['new_branch']]
        past_loc = branches.iloc[past_idx][['branch_x', 'branch_y']].values
        curr_loc = branches.iloc[curr_idx][['branch_x', 'branch_y']].values
        past_distances.append(np.linalg.norm(home - past_loc))
        current_distances.append(np.linalg.norm(home - curr_loc))
    past_mean = np.mean(past_distances) if past_distances else 0
    curr_mean = np.mean(current_distances) if current_distances else 0
    diff_metric = past_mean - curr_mean # 이 값이 양수면 거리 감소

    if diff_metric <= -1.0: # 현재 코드의 `if diff > -1.0: continue`의 실패 조건
        print(f"❌ 조건 불만족 (시도 {attempt}): 평균 거리 1 이상 증가 (변화량: {diff_metric:.2f})")
        continue

    # 6. 모든 검증 조건을 성공적으로 통과한 경우, 결과를 저장하고 루프 종료
    success = True
    filename = f"./data/rotation_assignments_final_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    final_df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"\n✅ 조건 충족 완료! (시도 {attempt}) 결과 저장: {filename}")
    print(f"▶ 지점별 인원: {branch_counts.to_dict()}")
    if not moved_4yrs_subset.empty:
         moved_percentage = 100.0 if moved_4yrs_subset['moved'].all() else (moved_4yrs_subset['moved'].sum() / len(moved_4yrs_subset) * 100)
         print(f"▶ 4년 이상 근무자 수(이동 대상): {len(moved_4yrs_subset)}명, 이동률: {moved_percentage:.2f}%")
    else:
        print(f"▶ 4년 이상 근무자 수(이동 대상): 0명")
    print(f"▶ 평균 거리 변화 (이전-현재): {diff_metric:.2f} (양수면 거리 감소)")
    break

# 7. 최대 시도 횟수 내에 모든 조건을 만족하는 해를 찾지 못한 경우, 최종 실패 메시지 출력
if not success:
    print(f"\n⚠️ 최대 반복 횟수({max_attempts})에 도달했지만 모든 조건을 충족하는 결과를 찾지 못했습니다.")
# Out:
# 1, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 2, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 3, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 4, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 5, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 6, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 7, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 8, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 9, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 10, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 11, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 12, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 13, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 14, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 15, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 16, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 17, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 18, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 19, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 20, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 21, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 22, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 23, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 24, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 25, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 26, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 27, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 28, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 29, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 30, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 31, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 32, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 33, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 34, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 35, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 36, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 37, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 38, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 39, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 40, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 41, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 42, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 43, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 44, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 45, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 46, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 47, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 48, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 49, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 50, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 51, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 52, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 53, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 54, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 55, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 56, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 57, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 58, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 59, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 60, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 61, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 62, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 63, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 64, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 65, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 66, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 67, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 68, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 69, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 70, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 71, ❌ 조건 불만족: 거리 감소폭이 0.41 > -1.0
# 72, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 73, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 74, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 75, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 76, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 77, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 78, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 79, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 80, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 81, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 82, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 83, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 84, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 85, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 86, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 87, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 88, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 89, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 90, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 91, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 92, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 93, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 94, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 95, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 96, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 97, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 98, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 99, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 100, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 101, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 102, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 103, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 104, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 105, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 106, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 107, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 108, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 109, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 110, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 111, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 112, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 113, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 114, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 115, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 116, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 117, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 118, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 119, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 120, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 121, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 122, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 123, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 124, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 125, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 126, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 127, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 128, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 129, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 130, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 131, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 132, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 133, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 134, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 135, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 136, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 137, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 138, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 139, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 140, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 141, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 142, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 143, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 144, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 145, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 146, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 147, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 148, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 149, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 150, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 151, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 152, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 153, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 154, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 155, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 156, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 157, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 158, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 159, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 160, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 161, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 162, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 163, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 164, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 165, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 166, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 167, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 168, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 169, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 170, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 171, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 172, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 173, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 174, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 175, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 176, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 177, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 178, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 179, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 180, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 181, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 182, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 183, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 184, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 185, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 186, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 187, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 188, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 189, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 190, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 191, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 192, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 193, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 194, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 195, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 196, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 197, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 198, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 199, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 200, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 201, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 202, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 203, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 204, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 205, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 206, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 207, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 208, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 209, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 210, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 211, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 212, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 213, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 214, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 215, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 216, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 217, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 218, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 219, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 220, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 221, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 222, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 223, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 224, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 225, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 226, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 227, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 228, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 229, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 230, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 231, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 232, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 233, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 234, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 235, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 236, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 237, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 238, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 239, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 240, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 241, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 242, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 243, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 244, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 245, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 246, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 247, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 248, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 249, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 250, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 251, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 252, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 253, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 254, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 255, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 256, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 257, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 258, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 259, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 260, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 261, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 262, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 263, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 264, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 265, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 266, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 267, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 268, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 269, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 270, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 271, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 272, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 273, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 274, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 275, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 276, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 277, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 278, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 279, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 280, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 281, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 282, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 283, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 284, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 285, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 286, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 287, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 288, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 289, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 290, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 291, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 292, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 293, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 294, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 295, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 296, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 297, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 298, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 299, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 300, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 301, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 302, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 303, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 304, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 305, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 306, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 307, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 308, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 309, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 310, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 311, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 312, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 313, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 314, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 315, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 316, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 317, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 318, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 319, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 320, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 321, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 322, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 323, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 324, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 325, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 326, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 327, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 328, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 329, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 330, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 331, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 332, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 333, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 334, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 335, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 336, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 337, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 338, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 339, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 340, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 341, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 342, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 343, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 344, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 345, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 346, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 347, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 348, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 349, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 350, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 351, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 352, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 353, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 354, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 355, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 356, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 357, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 358, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 359, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 360, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 361, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 362, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 363, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 364, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 365, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 366, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 367, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 368, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 369, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 370, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 371, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 372, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 373, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 374, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 375, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 376, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 377, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 378, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 379, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 380, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 381, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 382, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 383, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 384, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 385, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 386, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 387, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 388, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 389, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 390, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 391, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 392, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 393, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 394, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 395, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 396, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 397, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 398, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 399, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 400, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 401, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 402, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 403, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 404, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 405, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 406, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 407, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 408, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 409, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 410, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 411, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 412, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 413, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 414, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 415, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 416, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 417, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 418, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 419, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 420, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 421, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 422, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 423, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 424, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 425, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 426, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 427, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 428, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 429, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 430, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 431, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 432, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 433, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 434, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 435, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 436, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 437, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 438, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 439, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 440, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 441, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 442, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 443, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 444, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 445, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 446, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 447, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 448, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 449, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 450, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 451, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 452, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 453, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 454, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 455, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 456, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 457, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 458, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 459, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 460, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 461, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 462, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 463, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 464, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 465, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 466, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 467, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 468, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 469, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 470, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 471, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 472, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 473, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 474, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 475, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 476, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 477, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 478, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 479, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 480, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 481, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 482, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 483, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 484, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 485, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 486, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 487, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 488, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 489, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 490, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 491, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 492, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 493, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 494, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 495, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 496, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 497, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 498, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 499, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 500, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 501, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 502, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 503, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 504, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 505, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 506, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 507, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 508, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 509, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 510, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 511, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 512, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 513, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 514, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 515, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 516, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 517, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 518, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 519, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 520, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 521, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 522, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 523, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 524, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 525, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 526, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 527, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 528, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 529, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 530, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 531, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 532, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 533, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 534, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 535, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 536, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 537, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 538, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 539, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 540, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 541, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 542, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 543, ❌ 조건 불만족: 거리 감소폭이 -0.58 > -1.0
# 544, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 545, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 546, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 547, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 548, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 549, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 550, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 551, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 552, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 553, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 554, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 555, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 556, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 557, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 558, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 559, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 560, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 561, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 562, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 563, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 564, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 565, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 566, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 567, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 568, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 569, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 570, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 571, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 572, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 573, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 574, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 575, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 576, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 577, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 578, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 579, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 580, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 581, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 582, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 583, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 584, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 585, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 586, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 587, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 588, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 589, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 590, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 591, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 592, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 593, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 594, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 595, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 596, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 597, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 598, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 599, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 600, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 601, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 602, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 603, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 604, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 605, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 606, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 607, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 608, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 609, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 610, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 611, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 612, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 613, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 614, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 615, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 616, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 617, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 618, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 619, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 620, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 621, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 622, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 623, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 624, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 625, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 626, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 627, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 628, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 629, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 630, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 631, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 632, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 633, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 634, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 635, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 636, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 637, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 638, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 639, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 640, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 641, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 642, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 643, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 644, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 645, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 646, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 647, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 648, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 649, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 650, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 651, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 652, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 653, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 654, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 655, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 656, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 657, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 658, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 659, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 660, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 661, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 662, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 663, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 664, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 665, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 666, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 667, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 668, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 669, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 670, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 671, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 672, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 673, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 674, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 675, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 676, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 677, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 678, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 679, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 680, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 681, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 682, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 683, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 684, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 685, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 686, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 687, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 688, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 689, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 690, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 691, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 692, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 693, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 694, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 695, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 696, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 697, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 698, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 699, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 700, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 701, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 702, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 703, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 704, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 705, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 706, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 707, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 708, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 709, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 710, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 711, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 712, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 713, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 714, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 715, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 716, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 717, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 718, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 719, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 720, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 721, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 722, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 723, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 724, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 725, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 726, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 727, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 728, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 729, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 730, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 731, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 732, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 733, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 734, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 735, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 736, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 737, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 738, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 739, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 740, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 741, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 742, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 743, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 744, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 745, ❌ 조건 불만족: 일부 지점 인원수가 8~12명을 벗어남
# 746, ❌ 조건 불만족: 4년 이상 근무자 중 이동하지 않은 인원이 있음
# 747,
# ✅ 조건 충족 완료! 결과 저장: ./data/rotation_assignments_final_20250519_171618.csv
# ▶ 지점별 인원: {'Branch_7': 12, 'Branch_3': 12, 'Branch_8': 12, 'Branch_5': 10, 'Branch_4': 10, 'Branch_2': 10, 'Branch_0': 9, 'Branch_9': 9, 'Branch_6': 8, 'Branch_1': 8}
# ▶ 4년 이상 근무자 수: 30명, 이동률: 100%
# ▶ 평균 거리 감소: -1.22
