# %%
import gym
import numpy as np
import pandas as pd
import yfinance as yf
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt
import torch
import os
import optuna
import warnings
import random
warnings.filterwarnings("ignore")

# === STEP 0: 재현을 위한 시드 고정 ===
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)

# === STEP 1: 데이터 수집 함수 ===
def fetch_data(start, end):
    #(1) 학습에 사용할 대표 ETF 5종의 심볼을 리스트로 저장
    tickers = ["SPY", "TLT", "GLD", "DBC", "SHY"]

    #(2) 지정된 기간 동안의 일별 종가(Close) 데이터를 수집
    df = yf.download(tickers, start=start, end=end)["Close"]

    #(3) 결측치 제거
    df = df.dropna()

    #(4) 종가 데이터를 일간 수익률 데이터로 변환
    df = df.pct_change().dropna()
    return df

# ===  STEP 2. 사용자 정의 강화학습 환경 ===
class PortfolioEnvMonthly(gym.Env):
    
    #강화학습 환경의 기본 파라미터와 공간을 초기화
    def __init__(self, df, window_size=30, transaction_cost=0.002, rebalance_interval=20, seed=42):
        super().__init__()
        #(1) 수익률 데이터프레임(df) 저장
        self.df = df.reset_index(drop=True)

        #(2) 에이전트에게 제공할 입력의 기간 설정
        self.window_size = window_size

        #(3) 거래비용 설정
        self.transaction_cost = transaction_cost

        #(4) 자산 리밸런싱 주기 설정
        self.rebalance_interval = rebalance_interval

        #(5) 자산의 수(ETF 수)를 계산하여 저장
        self.asset_dim = df.shape[1]

        #(6) 에이전트 행동공간 정의
        self.action_space = spaces.Box(low=0, high=1, shape=(self.asset_dim,), dtype=np.float32)

        #(7) 관측 공간(observation space) 정의
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, self.asset_dim), dtype=np.float32
        )

        #(8) 환경 초기화
        self.seed(SEED)
        self.reset()

    def seed(self, seed=None):
        np.random.seed(seed)
        random.seed(seed)
        return [seed]

    def reset(self):
        #(1) 시뮬레이션 시작 시점 설정
        self.current_step = self.window_size

        #(2) 초기 포트폴리오 가치 설정
        self.portfolio_value = 1.0

        #(3) 초기 자산 비중 설정
        self.weights = np.array([1.0 / self.asset_dim] * self.asset_dim)

        #(4) 수익률 및 낙폭 기록 초기화
        self.portfolio_returns = []
        self.drawdowns = []

        #(5) 초기 상태 반환
        return self._get_observation()

    def _get_observation(self):
        return self.df.iloc[self.current_step - self.window_size:self.current_step].values

    def step(self, action):
        #(1) 행동 정규화 및 유효성 검증
        action = np.clip(action, 0, 1)
        if np.sum(action) == 0: #합계가 0일 경우(비정상적 행동) → 균등분배로 대체
            action = np.ones_like(action) / len(action)
        else: #그 외에는 합이 1이 되도록 정규화
            action /= np.sum(action)

        #(2) 이전 자산 비중 저장 및 새 비중 적용
        prev_weights = self.weights
        self.weights = action

        #(3) 리밸런싱 구간 설정
        end_step = min(self.current_step + self.rebalance_interval, len(self.df))
        segment = self.df.iloc[self.current_step:end_step].values

        #(4) 리밸런싱 기간 동안의 수익률 누적 및 낙폭 계산
        for daily_return in segment:
            #(4)-1 매일의 수익률 계산
            portfolio_return = np.dot(self.weights, daily_return)

            #(4)-2 포트폴리오 가치를 매일 누적 반영
            self.portfolio_value *= (1 + portfolio_return)

            #(4)-3 수익률 기록
            self.portfolio_returns.append(portfolio_return)

            #낙폭(drawdown) 계산: 최고점 대비 현재 가치의 하락률
            peak = max(self.portfolio_value, 1e-8)
            drawdown = 1 - self.portfolio_value / peak
            self.drawdowns.append(drawdown)

        #(5) 거래 비용 적용
        turnover = np.sum(np.abs(action - prev_weights))
        cost = turnover * self.transaction_cost
        self.portfolio_value -= cost

        #(6) 보상 계산
        reward = self._calculate_reward()

        #(7) 시점 이동 및 종료 조건 확인
        self.current_step = end_step
        done = self.current_step >= len(self.df) - 1

        #(8) 다음 상태 반환
        return self._get_observation(), reward, done, {'portfolio_value': self.portfolio_value}

    #한 리밸런싱 주기 동안의 투자성과를 평가하여 보상값으로 반환
    def _calculate_reward(self):
        #(1) 하이퍼파라미터 λ 설정
        λ1, λ2, λ3 = 3.0, 1.5, 0.5

        #(2) 샤프 비율 계산: 수익의 안정성을 평가
        if len(self.portfolio_returns) >= self.rebalance_interval:
            window_returns = np.array(self.portfolio_returns[-self.rebalance_interval:])
            mean_return = np.mean(window_returns) #평균수익률
            std_return = np.std(window_returns) #수익률 표준편차
            sharpe = mean_return / (std_return + 1e-8) #샤프 비율 = 평균 / 표준편차, 1e-8은 0으로 나누는 문제 방지
        else:
            sharpe = 0
        
        #(3) 최대 낙폭(Max Drawdown) 계산
        max_dd = max(self.drawdowns[-self.rebalance_interval:] or [0])

        #(4) 전체 로그 수익률 계산
        log_return = np.log(self.portfolio_value)  # 전체 로그 성장률

        #(5) 거래 패널티 (리밸런싱 강도): 극단적인 집중 투자에 페널티를 주려는 의도
        transaction_penalty = np.sum(np.abs(self.weights))

        #(6) 보상값 계산
        reward = log_return - λ1 * max_dd + λ2 * sharpe - λ3 * transaction_penalty
        return reward

def objective(trial):
    try:
        #(1) 하이퍼파라미터 탐색 공간 정의
        ent_coef = trial.suggest_loguniform("ent_coef", 0.01, 0.05)
        learning_rate = trial.suggest_loguniform("learning_rate", 0.0001, 0.001)
        clip_range = trial.suggest_uniform("clip_range", 0.1, 0.3)
        gamma = trial.suggest_uniform("gamma", 0.9, 0.999)
        net_arch = trial.suggest_categorical("net_arch", [[64, 32], [64, 64], [128, 64], [128, 128]])

        #(2) 정책 신경망 구조 구성
        policy_kwargs = dict(
            activation_fn=torch.nn.SiLU,
            net_arch=[dict(pi=net_arch, vf=net_arch)]
        )

        #(3) 학습 및 테스트 환경 초기화
        train_env = PortfolioEnvMonthly(train_df)
        train_env.seed(SEED)
        test_env = PortfolioEnvMonthly(test_df)
        test_env.seed(SEED)

        #(4) 초기 관측값 안정성 검사
        obs = train_env.reset()
        if np.isnan(obs).any() or np.isinf(obs).any():
            raise ValueError("🚫 초기 관측값에 NaN 또는 inf 포함")

        #(5) 모델 생성 및 학습
        model = PPO("MlpPolicy", train_env, verbose=0,
                    policy_kwargs=policy_kwargs,
                    ent_coef=ent_coef,
                    learning_rate=learning_rate,
                    clip_range=clip_range,
                    gamma=gamma,
                    seed=SEED
                   )

        model.learn(total_timesteps=150000)

        #(6) 검증 데이터셋을 통한 평가 수행
        mean_reward, _ = evaluate_policy(model, test_env, n_eval_episodes=4)

        #(7) 평가 결과의 유효성 확인
        if np.isnan(mean_reward) or np.isinf(mean_reward):
            raise ValueError("mean_reward 값이 NaN 또는 inf")

        #(8) 최종값 반환
        return mean_reward

    except Exception as e:
        print(f"Trial failed due to error: {e}")
        return float("inf")

#(9)학습 데이터와 테스트 데이터 분리 
train_df = fetch_data("2005-01-01", "2023-12-31")
test_df = fetch_data("2024-01-01", "2025-03-31")

#(10) Optuna 스터디 객체 생성
study = optuna.create_study(direction="maximize")

#(11) 최적화 실행
study.optimize(objective, n_trials=50)

#(12) 최적 결과 요약 출력
print("Best trial found:")
print(f"Mean reward (test set): {-study.best_trial.value}")
print("Best hyperparameters:")
for k, v in study.best_trial.params.items():
    print(f"{k}: {v}")
# Out:
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  5 of 5 completed
# [I 2025-04-07 20:15:07,526] A new study created in memory with name: no-name-81bc6560-1f48-49e6-94a1-e68260aa9331
# [I 2025-04-07 20:17:51,757] Trial 0 finished with value: -2.980326747521758 and parameters: {'ent_coef': 0.012564753058881738, 'learning_rate': 0.00010147047558286817, 'clip_range': 0.14920069144706022, 'gamma': 0.9908804583223927, 'net_arch': [64, 32]}. Best is trial 0 with value: -2.980326747521758.
# [I 2025-04-07 20:20:40,928] Trial 1 finished with value: -2.9898447687737644 and parameters: {'ent_coef': 0.021517266538788656, 'learning_rate': 0.0001295706988033356, 'clip_range': 0.10097027394502969, 'gamma': 0.9039461674516609, 'net_arch': [128, 128]}. Best is trial 0 with value: -2.980326747521758.
# [I 2025-04-07 20:23:55,203] Trial 2 finished with value: -2.980326747521758 and parameters: {'ent_coef': 0.010148447134522568, 'learning_rate': 0.0001976647136678799, 'clip_range': 0.2978110545559157, 'gamma': 0.9132161304839778, 'net_arch': [64, 32]}. Best is trial 0 with value: -2.980326747521758.
# [I 2025-04-07 20:27:22,330] Trial 3 finished with value: -3.1485609635710716 and parameters: {'ent_coef': 0.01721168971686975, 'learning_rate': 0.00019273980289898733, 'clip_range': 0.2179355674964109, 'gamma': 0.944552059964445, 'net_arch': [128, 128]}. Best is trial 0 with value: -2.980326747521758.
# [I 2025-04-07 20:30:39,152] Trial 4 finished with value: -3.1589703890495002 and parameters: {'ent_coef': 0.010357764478549417, 'learning_rate': 0.0001659984248661914, 'clip_range': 0.24530156730232514, 'gamma': 0.9220113271788389, 'net_arch': [64, 64]}. Best is trial 0 with value: -2.980326747521758.
# [I 2025-04-07 20:33:59,694] Trial 5 finished with value: -2.5096609937027097 and parameters: {'ent_coef': 0.04702171538251352, 'learning_rate': 0.00012307631729099522, 'clip_range': 0.29285226525264163, 'gamma': 0.9844242691296968, 'net_arch': [128, 128]}. Best is trial 5 with value: -2.5096609937027097.
# [I 2025-04-07 22:30:22,694] Trial 46 finished with value: -1.6015385538339615 and parameters: {'ent_coef': 0.02145081195992673, 'learning_rate': 0.00013688911094993954, 'clip_range': 0.2553062548731279, 'gamma': 0.9850027529982414, 'net_arch': [128, 64]}. Best is trial 44 with value: -1.4605995118618011.
# [I 2025-04-07 22:33:02,200] Trial 47 finished with value: -2.33869365171995 and parameters: {'ent_coef': 0.022384361855662317, 'learning_rate': 0.00013636681833208153, 'clip_range': 0.2641447240389678, 'gamma': 0.9735518720157562, 'net_arch': [128, 64]}. Best is trial 44 with value: -1.4605995118618011.
# [I 2025-04-07 22:35:42,584] Trial 48 finished with value: -1.390946865081787 and parameters: {'ent_coef': 0.02739631748465051, 'learning_rate': 0.000121589065980159, 'clip_range': 0.23371918064649302, 'gamma': 0.9850779752296994, 'net_arch': [128, 64]}. Best is trial 48 with value: -1.390946865081787.
# [I 2025-04-07 22:38:24,613] Trial 49 finished with value: -1.5265349447727203 and parameters: {'ent_coef': 0.027734980564164118, 'learning_rate': 0.0001209799268684153, 'clip_range': 0.2246630635024872, 'gamma': 0.9793422403233359, 'net_arch': [128, 64]}. Best is trial 48 with value: -1.390946865081787.
# ✅ Best trial found:
# Mean reward (test set): 1.390946865081787
# Best hyperparameters:
# ent_coef: 0.02739631748465051
# learning_rate: 0.000121589065980159
# clip_range: 0.23371918064649302
# gamma: 0.9850779752296994
# net_arch: [128, 64]

# %%
#(1) 상위 trial 5개 추출
top_trials = sorted(study.trials, key=lambda t: t.value, reverse=True)[:5]

#(2) 결과출력
print("Top 5 Trials (Sorted by Mean Reward on Test Set):\n")
for i, trial in enumerate(top_trials, 1):
    print(f"Rank {i}:")
    print(f"Mean reward (test set): {trial.value:.5f}")
    print("Hyperparameters:")
    for k, v in trial.params.items():
        print(f"     - {k}: {v}")
    print("-" * 40)
# Out:
# Top 5 Trials (Sorted by Mean Reward on Test Set):
#
# Rank 1:
# Mean reward (test set): -1.39095
# Hyperparameters:
#      - ent_coef: 0.02739631748465051
#      - learning_rate: 0.000121589065980159
#      - clip_range: 0.23371918064649302
#      - gamma: 0.9850779752296994
#      - net_arch: [128, 64]
# ----------------------------------------
# Rank 2:
# Mean reward (test set): -1.46060
# Hyperparameters:
#      - ent_coef: 0.023080979643558968
#      - learning_rate: 0.00010264714310572373
#      - clip_range: 0.2750425548167692
#      - gamma: 0.9848797764818369
#      - net_arch: [128, 64]
# ----------------------------------------
# Rank 3:
# Mean reward (test set): -1.52653
# Hyperparameters:
#      - ent_coef: 0.027734980564164118
#      - learning_rate: 0.0001209799268684153
#      - clip_range: 0.2246630635024872
#      - gamma: 0.9793422403233359
#      - net_arch: [128, 64]
# ----------------------------------------
# Rank 4:
# Mean reward (test set): -1.58780
# Hyperparameters:
#      - ent_coef: 0.020565267255812973
#      - learning_rate: 0.00014192465923091677
#      - clip_range: 0.26682807015419296
#      - gamma: 0.985603869475342
#      - net_arch: [128, 64]
# ----------------------------------------
# Rank 5:
# Mean reward (test set): -1.60154
# Hyperparameters:
#      - ent_coef: 0.02145081195992673
#      - learning_rate: 0.00013688911094993954
#      - clip_range: 0.2553062548731279
#      - gamma: 0.9850027529982414
#      - net_arch: [128, 64]
# ----------------------------------------

# %%
# === STEP 3: 학습용 데이터 로딩 및 학습 ===
#(1) 학습용 데이터 수집
train_df = fetch_data("2005-01-01", "2023-12-31")

#(2) 사용자 환경 설정2
train_env = PortfolioEnvMonthly(train_df)
train_env.seed(SEED)

policy_kwargs = dict(
    activation_fn=torch.nn.SiLU,  # Swish = SiLU
    net_arch=[dict(pi=[128,64], vf=[128,64])]
)
#(3) PPO 에이전트 초기화
model = PPO("MlpPolicy", train_env, verbose=1, policy_kwargs=policy_kwargs, seed=SEED,
            clip_range=0.2750425548167692, gamma=0.9848797764818369,
            ent_coef=0.023080979643558968, learning_rate=0.00010264714310572373,
            tensorboard_log="./ppo_tensorboard_logs/"
           )

#(4) 학습시작
model.learn(total_timesteps=300000, log_interval=10)

# === STEP 4: 모델 저장 ===
#(1) 모델 저장 폴더 생성
os.makedirs("models", exist_ok=True)

#(2) 모델 경로 설정
model_path = "models/ray_dalio_portfolio_model"

#(3) 학습된 모델 저장
model.save(model_path)

print(f"모델 저장 완료: {model_path}.zip")

# === STEP 5: 검증용 2024년도 데이터 로딩 및 모델 로딩 ===
#(1) 테스트 데이터 수집
test_df = fetch_data("2024-01-01", "2025-03-31")
test_env = PortfolioEnvMonthly(test_df)

#(2) 저장된 모델 로딩
loaded_model = PPO.load(model_path, env=test_env)

#(3) 환경 초기화 및 초기 상태 준비
obs = test_env.reset()
portfolio_values = [test_env.portfolio_value]
done = False

#(4) 행동 정규화 함수 정의
def normalize_action(action):
    action = np.maximum(action, 0)
    total = np.sum(action)
    return action / total if total > 0 else np.ones_like(action) / len(action)

#(5) 시뮬레이션 실행
while not done:
    action, _ = loaded_model.predict(obs, deterministic=True)
    action = normalize_action(action)
    obs, reward, done, info = test_env.step(action)
    portfolio_values.append(info['portfolio_value'])

#(6) 결과 시각화
plt.plot(portfolio_values)
plt.title("2024 Evaluation Results (RL Asset Allocation Strategy)")
plt.xlabel("Time Step")
plt.ylabel("Portfolio Value")
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./ppo_tensorboard_logs/PPO_3
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -33.7        |
# | time/                   |              |
# |    fps                  | 993          |
# |    iterations           | 10           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0033317169 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.275        |
# |    entropy_loss         | -7.22        |
# |    explained_variance   | 0.0513       |
# |    learning_rate        | 0.000103     |
# |    loss                 | 13.8         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00189     |
# |    std                  | 1.03         |
# |    value_loss           | 26.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -33.8       |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 20          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005684097 |
# |    clip_fraction        | 0.00278     |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -7.33       |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 9.06        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 1.05        |
# |    value_loss           | 19          |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 224           |
# |    ep_rew_mean          | -27.4         |
# | time/                   |               |
# |    fps                  | 963           |
# |    iterations           | 30            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00068774726 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.275         |
# |    entropy_loss         | -7.47         |
# |    explained_variance   | 0.169         |
# |    learning_rate        | 0.000103      |
# |    loss                 | 11.4          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000921     |
# |    std                  | 1.08          |
# |    value_loss           | 19.7          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -30.4       |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 40          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009687608 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -7.58       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 13.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00521    |
# |    std                  | 1.1         |
# |    value_loss           | 28.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -9.46        |
# | time/                   |              |
# |    fps                  | 962          |
# |    iterations           | 50           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0007049281 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.275        |
# |    entropy_loss         | -7.7         |
# |    explained_variance   | 0.274        |
# |    learning_rate        | 0.000103     |
# |    loss                 | 19.6         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000481    |
# |    std                  | 1.13         |
# |    value_loss           | 36.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | 9.02         |
# | time/                   |              |
# |    fps                  | 962          |
# |    iterations           | 60           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0029319483 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.275        |
# |    entropy_loss         | -7.81        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.000103     |
# |    loss                 | 5.92         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000892    |
# |    std                  | 1.16         |
# |    value_loss           | 18.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 224        |
# |    ep_rew_mean          | 16.8       |
# | time/                   |            |
# |    fps                  | 960        |
# |    iterations           | 70         |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.01332355 |
# |    clip_fraction        | 0.041      |
# |    clip_range           | 0.275      |
# |    entropy_loss         | -7.91      |
# |    explained_variance   | 0.498      |
# |    learning_rate        | 0.000103   |
# |    loss                 | 6.3        |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.00951   |
# |    std                  | 1.18       |
# |    value_loss           | 17.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 23.3        |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 80          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007566265 |
# |    clip_fraction        | 0.00894     |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 11.5        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00302    |
# |    std                  | 1.2         |
# |    value_loss           | 18.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 33.8        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 90          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.009005072 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 8.66        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00483    |
# |    std                  | 1.23        |
# |    value_loss           | 23.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 23.8        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 100         |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.006778698 |
# |    clip_fraction        | 0.00894     |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.22       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 7.43        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 1.25        |
# |    value_loss           | 18.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 35.5        |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 110         |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.007838655 |
# |    clip_fraction        | 0.00635     |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.36       |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 10.6        |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 1.29        |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 42          |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 120         |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.008231737 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.47       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 11.8        |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.00461    |
# |    std                  | 1.32        |
# |    value_loss           | 22.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 38.9        |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 130         |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.008413267 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.55       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 11.6        |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00393    |
# |    std                  | 1.34        |
# |    value_loss           | 22.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 33.4        |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 140         |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.008750355 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.275       |
# |    entropy_loss         | -8.7        |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.000103    |
# |    loss                 | 8.47        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0032     |
# |    std                  | 1.38        |
# |    value_loss           | 17.2        |
# -----------------------------------------
# [*********************100%***********************]  5 of 5 completed
# 모델 저장 완료: models/ray_dalio_portfolio_model.zip
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
